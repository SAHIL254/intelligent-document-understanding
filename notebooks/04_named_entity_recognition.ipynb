# %% [markdown]
# ---
# # OBJECTIVE
# ---
# # Goal:
# Automatically extract named entities such as:
#  - PERSON
#  - ORG
#  - GPE (locations)
#  - DATE
#  - MONEY
#
# # From unstructured text documents using spaCy.
# #
# # Key Notes:
#  - NER uses ORIGINAL text (not cleaned text)
#  - Lowercasing and punctuation removal can reduce NER quality
#  - We use a pretrained industrial NLP pipeline
#  - CPU-only implementation
# ---

# %% [markdown]
# ## 🔹 Reality of Notebook 04 (NER)
#
# ### 1. NER does NOT use cleaned text
#
# Lowercasing, punctuation removal, or TF-IDF preprocessing can reduce entity recognition quality.
#
# spaCy models rely heavily on:
# - capitalization
# - punctuation
# - sentence structure
#
# for accurate entity extraction.
#
# ---
#
# ### 2. Classification preprocessing is separate
#
# - Notebook 03 uses `clean_text` for TF-IDF + Logistic Regression
# - Notebook 04 uses raw `full_text` for spaCy NER
#
# Different NLP tasks require different preprocessing strategies.

# %% [markdown]
# # STEP 1: Imports

# %%
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # STEP 2: Load spaCy model
# * en_core_web_sm:
# * Pretrained English NLP pipeline
# * Supports tokenization, POS tagging, parsing, and NER

# %%
nlp = spacy.load("en_core_web_sm")
print("spaCy model loaded successfully.")
# Out:
# spaCy model loaded successfully.

# %% [markdown]
# # STEP 3: Load raw dataset

# %% [markdown]
# # IMPORTANT:
# * We use RAW text here.
# * NER should not use aggressively cleaned text.

# %%
bbc_df = pd.read_csv(
    "../data/bbc-news-data.csv",
    sep="\t",
    engine="python"
)

print("Dataset shape:", bbc_df.shape)

bbc_df.head()
# Out:
# Dataset shape: (2225, 4)
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %% [markdown]
# # STEP 4: Combine Title + Content

# %%
bbc_df["full_text"] = bbc_df["title"] + ". " + bbc_df["content"]

bbc_df[["category", "full_text"]].head()
# Out:
#    category                                          full_text
# 0  business  Ad sales boost Time Warner profit.  Quarterly ...
# 1  business  Dollar gains on Greenspan speech.  The dollar ...
# 2  business  Yukos unit buyer faces loan claim.  The owners...
# 3  business  High fuel prices hit BA's profits.  British Ai...
# 4  business  Pernod takeover talk lifts Domecq.  Shares in ...

# %% [markdown]
# # STEP 5: Run NER on Single Sample Document

# %%
sample_text = bbc_df.loc[0, "full_text"]

doc = nlp(sample_text)

# Extract entities
entities = [(ent.text, ent.label_) for ent in doc.ents]

entities[:20]
# Out:
# [('Time Warner', 'ORG'),
#  ('Quarterly', 'DATE'),
#  ('US', 'GPE'),
#  ('TimeWarner', 'ORG'),
#  ('76%', 'PERCENT'),
#  ('1.13bn', 'MONEY'),
#  ('600', 'MONEY'),
#  ('the three months to December', 'DATE'),
#  ('639', 'MONEY'),
#  ('year-earlier', 'DATE'),
#  ('Google', 'ORG'),
#  ('TimeWarner', 'ORG'),
#  ('fourth quarter', 'DATE'),
#  ('2%', 'PERCENT'),
#  ('11.1bn', 'MONEY'),
#  ('10.9bn', 'MONEY'),
#  ('one', 'CARDINAL'),
#  ('Warner Bros', 'ORG'),
#  ('AOL', 'ORG'),
#  ('Time Warner', 'ORG')]

# %% [markdown]
# # STEP 6: Visualize entities

# %% [markdown]
# # NOTE:
# * Visualization works best in Jupyter locally

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ad sales boost
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Time Warner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  profit.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  profits at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
# ...

# %% [markdown]
# # STEP 7: Batch Entity Extraction (Production-Oriented)

# %%
docs = list(
    nlp.pipe(
        bbc_df["full_text"],
        batch_size=32
    )
)

# Store extracted entities
bbc_df["entities"] = [
    [(ent.text, ent.label_) for ent in doc.ents]
    for doc in docs
]

bbc_df[["entities"]].head()
# Out:
#                                             entities
# 0  [(Time Warner, ORG), (Quarterly, DATE), (US, G...
# 1  [(Greenspan, PERSON), (almost three months, DA...
# 2  [(Yukos, ORG), (Russian, NORP), (Yukos, PERSON...
# 3  [(BA, ORG), (British Airways, ORG), (40%, PERC...
# 4  [(Pernod, PERSON), (Domecq, PRODUCT), (UK, GPE...

# %% [markdown]
# # STEP 8: Filter Important Entity Types (PERSON, ORG, GPE....)

# %%
IMPORTANT_LABELS = (
    "PERSON",
    "ORG",
    "GPE",
    "DATE",
    "MONEY"
)

def filter_entities(entities, labels=IMPORTANT_LABELS):
    return [
        ent for ent in entities
        if ent[1] in labels
    ]

bbc_df["key_entities"] = (
    bbc_df["entities"]
    .apply(filter_entities)
)

bbc_df[["key_entities"]].head()
# Out:
#                                         key_entities
# 0  [(Time Warner, ORG), (Quarterly, DATE), (US, G...
# 1  [(Greenspan, PERSON), (almost three months, DA...
# 2  [(Yukos, ORG), (Yukos, PERSON), ($900m, MONEY)...
# 3  [(BA, ORG), (British Airways, ORG), (the three...
# 4  [(Pernod, PERSON), (UK, GPE), (Allied Domecq, ...

# %% [markdown]
# # STEP 9: Entity Frequency Analysis

# %%
all_entities = []

for entity_list in bbc_df["key_entities"]:
    all_entities.extend(entity_list)

entity_counter = Counter(all_entities)

top_entities = entity_counter.most_common(10)

print("Top 10 Most Common Entities:\n")

for entity, count in top_entities:
    print(f"{entity} -> {count}")
# Out:
# Top 10 Most Common Entities:
#
# ('US', 'GPE') -> 1510
# ('UK', 'GPE') -> 1043
# ('England', 'GPE') -> 515
# ('Labour', 'ORG') -> 466
# ('Britain', 'GPE') -> 400
# ('2004', 'DATE') -> 381
# ('London', 'GPE') -> 367
# ('France', 'GPE') -> 330
# ('BBC', 'ORG') -> 318
# ('2005', 'DATE') -> 304

# %% [markdown]
# # STEP 10: Visualize Top Entities

# %%
labels = [f"{x[0][0]} ({x[0][1]})" for x in top_entities]
counts = [x[1] for x in top_entities]

plt.figure(figsize=(12, 5))

plt.bar(labels, counts)

plt.title("Top Named Entities")
plt.xlabel("Entity")
plt.ylabel("Frequency")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # STEP 11: Save Processed NER Artifacts

# %%
ner_results = bbc_df[
    ["category", "full_text", "key_entities"]
]

ner_results.to_csv(
    "../artifacts/bbc_with_entities.csv",
    index=False
)
print("NER artifacts saved successfully.")
# Out:
# NER artifacts saved successfully.
