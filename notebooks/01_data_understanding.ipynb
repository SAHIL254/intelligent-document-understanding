# %% [markdown]
# **Business Understanding (This is the CORE)**
# # 🔴 Business Problem (Plain English)
#
# “We receive thousands of text documents.
# Humans cannot read and process them fast enough.
# We need automation.”
#
# # 🔴 Business Impact
#
# Manual cost ↓
#
# Processing time ↓
#
# Errors ↓
#
# Decision speed ↑
#
# 📌 This is a cost-saving + efficiency ML problem.

# %% [markdown]
# # 1️⃣ Load BBC dataset

# %%
import os
os.listdir("../data")

import matplotlib.pyplot as plt

# %%
import pandas as pd

bbc_df = pd.read_csv(
    "../data/bbc-news-data.csv",
    sep="\t",
    engine="python"
)

bbc_df.head()
# Out:
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %%
bbc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  2225 non-null   object
#  1   filename  2225 non-null   object
#  2   title     2225 non-null   object
#  3   content   2225 non-null   object
# dtypes: object(4)
# memory usage: 69.7+ KB

# %%
bbc_df.columns
# Out:
# Index(['category', 'filename', 'title', 'content'], dtype='object')

# %%
bbc_df.isnull().sum()
# Out:
# category    0
# filename    0
# title       0
# content     0
# dtype: int64

# %%
bbc_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
bbc_df['category'].value_counts()
# Out:
# category
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64

# %%
bbc_df['title'].str.len().describe()
# Out:
# count    2225.000000
# mean       31.367191
# std         2.605422
# min        16.000000
# 25%        31.000000
# 50%        32.000000
# 75%        33.000000
# max        52.000000
# Name: title, dtype: float64

# %%
bbc_df['category'].value_counts().plot(kind='bar')
plt.title("Category Distribution")
plt.show()

# %%
bbc_df['title'].str.len().hist(bins=50)
plt.title("Distribution of Title Lengths")
plt.show()

# %%
from wordcloud import WordCloud
text = " ".join(bbc_df['title'])
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **“All NLP tasks (Classification, NER, Summarization) will use BBC news dataset for consistency and CPU-friendly processing.”**
